# %% [markdown]
# ### IMPORTING LIBRARIES AND LOADING DATASETS

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Exploratory Data Analysis Libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# Plotly
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
import plotly.offline as offline
import plotly.graph_objs as go
offline.init_notebook_mode(connected = True)
import calendar
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
holidays = pd.read_csv('holidays_events.csv', parse_dates=['date'])
oil = pd.read_csv('oil.csv', parse_dates=['date'])
stores = pd.read_csv('stores.csv')
transactions = pd.read_csv('transactions.csv', parse_dates=['date'])
train = pd.read_csv('train.csv', parse_dates=['date'])
test = pd.read_csv('test.csv', parse_dates=['date'])
# Out:
# ((28512, 5), (3000888, 6))

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %%
# Check first rows and data types
print(train.head())

# Summary of numerical columns
print(train.describe())
# Out:
#          date  store_nbr      family  sales  onpromotion  SalePrice
# id
# 0  2013-01-01          1  AUTOMOTIVE    0.0            0        NaN
# 1  2013-01-01          1   BABY CARE    0.0            0        NaN
# 2  2013-01-01          1      BEAUTY    0.0            0        NaN
# 3  2013-01-01          1   BEVERAGES    0.0            0        NaN
# 4  2013-01-01          1       BOOKS    0.0            0        NaN
#                                 date     store_nbr         sales  \
# count                        3029400  3.029400e+06  3.000888e+06
# mean   2015-05-02 08:56:11.294118144  2.750000e+01  3.577757e+02
# min              2013-01-01 00:00:00  1.000000e+00  0.000000e+00
# 25%              2014-03-02 18:00:00  1.400000e+01  0.000000e+00
# 50%              2015-05-02 12:00:00  2.750000e+01  1.100000e+01
# 75%              2016-07-01 06:00:00  4.100000e+01  1.958473e+02
# max              2017-08-31 00:00:00  5.400000e+01  1.247170e+05
# std                              NaN  1.558579e+01  1.101998e+03
#
#         onpromotion  SalePrice
# count  3.029400e+06    28512.0
# mean   2.643830e+00        0.0
# min    0.000000e+00        0.0
# 25%    0.000000e+00        0.0
# 50%    0.000000e+00        0.0
# 75%    0.000000e+00        0.0
# max    7.410000e+02        0.0
# std    1.233287e+01        0.0

# %%
# Count missing values per column
train.isnull().sum()
# Out:
# date                 0
# store_nbr            0
# family               0
# sales            28512
# onpromotion          0
# SalePrice      3000888
# dtype: int64

# %%
# Daily total sales
train.groupby('date')['sales'].sum().plot(figsize=(12,4), title='Total Sales Over Time')
# Out:
# <Axes: title={'center': 'Total Sales Over Time'}, xlabel='date'>

# %%
train.groupby(train['date'].dt.dayofweek)['sales'].mean().plot(
    kind='bar', title='Average Sales by Day of Week'
)
# Out:
# <Axes: title={'center': 'Average Sales by Day of Week'}, xlabel='date'>

# %%
train.groupby(train['date'].dt.month)['sales'].mean().plot(
    kind='bar', title='Average Sales by Month'
)
# Out:
# <Axes: title={'center': 'Average Sales by Month'}, xlabel='date'>

# %%
train.groupby('store_nbr')['sales'].mean().sort_values(ascending=False).plot(
    kind='bar', figsize=(12,4), title='Average Sales per Store'
)
# Out:
# <Axes: title={'center': 'Average Sales per Store'}, xlabel='store_nbr'>

# %%
train.groupby('family')['sales'].mean().sort_values(ascending=False).plot(
    kind='barh', figsize=(8,6), title='Average Sales per Product Family'
)
# Out:
# <Axes: title={'center': 'Average Sales per Product Family'}, ylabel='family'>
